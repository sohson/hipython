# %% [markdown]
# # 시각화 라이브러리 설치

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# # 설정: 경고와 한글폰트 적용

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
# 폰트 지정
from matplotlib import rcParams
rcParams['font.family'] = 'Gulim'  
rcParams['axes.unicode_minus'] = False  # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상 해결

# %%
import matplotlib.pyplot as plt
plt.title('클래스와 오브젝트')
plt.xlabel('클래스')
plt.ylabel('오브젝트')
# Out:
# Text(0, 0.5, '오브젝트')

# %% [markdown]
# # 시각화의 필요성

# %%
anscombe = sns.load_dataset('anscombe')
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
d1 = anscombe[anscombe['dataset']=='I']
d2 = anscombe[anscombe['dataset']=='II']
d3 = anscombe[anscombe['dataset']=='III']
d4 = anscombe[anscombe['dataset']=='IV']

d1.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031568
# min     4.000000   4.260000
# 25%     6.500000   6.315000
# 50%     9.000000   7.580000
# 75%    11.500000   8.570000
# max    14.000000  10.840000

# %%
plt.plot(d1['x'], d1['y'],'o')

# %%
plt.plot(d2['x'], d2['y'],'o')

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2,2,1) #2row, 2col,position
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

axes1.plot( d1['x'], d1['y'] , 'o')
axes2.plot( d2['x'], d2['y'] , 'o')
axes3.plot( d3['x'], d3['y'] , 'o')
axes4.plot( d4['x'], d4['y'] , 'o')

axes1.set_title('dataset I')
axes2.set_title('dataset II')
axes3.set_title('dataset III')
axes4.set_title('dataset IV')

fig.suptitle('Anscombe Dataset 으로 보는 데이터 시각화의 의미')
fig.set_tight_layout(True)
plt.show()

# %%
dates = ['2024-10-01', '2024-10-02', '2024-10-03', '2024-10-04', '2024-10-05']
prices = [100, 102, 101, 105, 103]

# %%
plt.figure(figsize=(10,4)) # 차트 크기

# %%
plt.subplot(1,2,1)
plt.plot(dates, prices, marker='o')

plt.subplot(1,2,2)
plt.bar(dates, prices)

plt.savefig('my_chart.png')

# %% [markdown]
# # 용도에 맞는 차트 그리기

# %%
tips_df=sns.load_dataset('tips')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## 1변량 그래프

# %% [markdown]
# ### 히스토그램
# - 구간, 빈도수

# %%
plt.hist(data=tips_df, x='total_bill', bins=10, color='pink', edgecolor='black', rwidth=0.8)
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <BarContainer object of 10 artists>)

# %%
# total_bill vs tip
plt.subplot(1,2,1)
plt.hist(data=tips_df, x='total_bill', bins=10, color='pink', edgecolor='white', rwidth=0.8)
plt.title('Total Bill')
plt.subplot(1,2,2)
plt.hist(data=tips_df, x='tip', bins=10, color='lightblue', edgecolor='white', rwidth=0.8)
plt.title('Tip')
# Out:
# Text(0.5, 1.0, 'Tip')

# %% [markdown]
# ### boxplot

# %%
plt.boxplot([tips_df['total_bill'], tips_df['tip']], labels=['Total Bill', 'Tip'])
#plt.grid()
plt.show()

# %%
plt.boxplot(
  [tips_df[tips_df['sex']=='Female']['total_bill'],
  tips_df[tips_df['sex']=='Female']['tip']], 
  labels = ['Total Bill', 'Tip'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x17866ece830>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x17866eced10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x17866ece530>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x17866ecf310>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x17866ecf610>,
# ...
#  'means': []}

# %%
plt.boxplot(
  [tips_df[tips_df['sex']=='Male']['total_bill'],
  tips_df[tips_df['sex']=='Male']['tip']], 
  labels = ['Total Bill', 'Tip'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x17866f582e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x17866f58910>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x17866f58100>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x17866f58f10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x17866f59210>,
# ...
#  'means': []}

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_df.groupby(['day','time']).size()
# Out:
# day   time
# Thur  Lunch     61
#       Dinner     1
# Fri   Lunch      7
#       Dinner    12
# Sat   Lunch      0
#       Dinner    87
# Sun   Lunch      0
#       Dinner    76
# dtype: int64

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6)) # 1행 3열, 크기


# 요일별 팁 분포 
sns.boxplot(ax=axes[0], x='day', y='tip', data=tips_df, palette='Set3')
axes[0].set_title('Tip Distribution by Day') # 0번째(첫번째) 칸에 그려라

# 시간대별 팁 분포
sns.boxplot(ax=axes[1], x='time', y='tip', data=tips_df, palette='Pastel1')
axes[1].set_title('Tip Distribution by Time')

# 요일 및 시간대별 평균 팁 
sns.barplot(ax=axes[2], x='day', y='tip', hue='time', data=tips_df, palette='Pastel2')
axes[2].set_title('Average Tip by Day and Time')

plt.tight_layout() # 그래프 간격 자동 조절 >> 제목이나 축 레이블이 겹치는 현상 방지

# %% [markdown]
# - 토요일, 일요일의 팁 금액범위가 평일보다 높음 >> 주말에 제공되는 요리나 서비스의 퀄리티 향상에 투자하는 것이 높은 팁을 얻기에 효율적
# - 점심보다 저녁의 평균 팁이 높음 >>
# - 토요일은 팁의 분포가 넓음 >> 비일상적인 소비가 많음

# %%
import numpy as np

thur_lunch_m = tips_df[(tips_df['day'] == 'Thur') & (tips_df['time'] == 'Lunch')]['tip'].mean()
thur_dinner_m = tips_df[(tips_df['day'] == 'Thur') & (tips_df['time'] == 'Dinner')]['tip'].mean()

fri_lunch_m = tips_df[(tips_df['day'] == 'Fri') & (tips_df['time'] == 'Lunch')]['tip'].mean()
fri_dinner_m = tips_df[(tips_df['day'] == 'Fri') & (tips_df['time'] == 'Dinner')]['tip'].mean()

sat_lunch_m = tips_df[(tips_df['day'] == 'Sat') & (tips_df['time'] == 'Lunch')]['tip'].mean()
sat_dinner_m = tips_df[(tips_df['day'] == 'Sat') & (tips_df['time'] == 'Dinner')]['tip'].mean()

sun_lunch_m = tips_df[(tips_df['day'] == 'Sun') & (tips_df['time'] == 'Lunch')]['tip'].mean()
sun_dinner_m = tips_df[(tips_df['day'] == 'Sun') & (tips_df['time'] == 'Dinner')]['tip'].mean()

x = np.arange(4) 
width = 0.3 

plt.bar(x - width/2, [thur_lunch_m, fri_lunch_m, sat_lunch_m, sun_lunch_m], width, label='Lunch', color='skyblue')
plt.bar(x + width/2, [thur_dinner_m, fri_dinner_m, sat_dinner_m, sun_dinner_m], width, label='Dinner', color='salmon')

plt.xticks(x, ['Thur', 'Fri', 'Sat', 'Sun'])
plt.title('Average Tip by Day & Time')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # seaborn 시각화

# %%
df_tips = sns.load_dataset('tips')
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(data=df_tips,x='total_bill', y='tip', 
            col='time',
            hue='smoker',
            style='time',size='size')

# %%
sns.scatterplot(data=df_tips,x='total_bill',y='tip',hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.regplot(x=df_tips['total_bill'],y=df_tips['tip'],
            scatter_kws={'s':30,'color':'blue'},
            line_kws={'color':'red'})
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.pointplot(x=df_tips['day'], y=df_tips['tip'])
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# # 통계량 표현

# %%
sns.boxplot(x='day',y='total_bill',data=df_tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='size',y='tip',data=df_tips)
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
sns.violinplot(x='size',y='tip',data=df_tips)
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
sns.histplot(df_tips['tip'], bins=10, kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.kdeplot(df_tips['tip'], fill=True)
sns.rugplot(df_tips['tip'], height=0.08, alpha=0.5, color='black')
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.heatmap(df_tips.corr(numeric_only=True),annot=True, cmap='Blues')
# Out:
# <Axes: >

# %%
df_tips.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# 범주형변수 > pivottable > heatmap
pivot_df= df_tips.pivot_table('tip','day','size',aggfunc='count')
pivot_df
# Out:
# size     1         2         3         4         5    6
# day
# Thur  1.83  2.442500  2.692500  4.218000  5.000000  5.3
# Fri   1.92  2.644375  3.000000  4.730000       NaN  NaN
# Sat   1.00  2.517547  3.797778  4.123846  3.000000  NaN
# Sun    NaN  2.816923  3.120667  4.087778  4.046667  5.0

# %%
# size별, day별 tip 건수의 관계
sns.heatmap(pivot_df,annot=True,cmap='YlGnBu')
# Out:
# <Axes: xlabel='size', ylabel='day'>

# %%
pivot_df_2= df_tips.pivot_table('tip','time','sex',aggfunc='count')
pivot_df_2
# Out:
# sex     Male  Female
# time
# Lunch     33      35
# Dinner   124      52

# %%
sns.heatmap(pivot_df_2,annot=True,cmap='Blues')
# Out:
# <Axes: xlabel='sex', ylabel='time'>

# %% [markdown]
# # 큰데이터 시각화

# %%
df_dia=sns.load_dataset('diamonds')
df_dia
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.lmplot(df_dia,x='carat',y='price',hue='cut',col='cut')

# %%
df_dia.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
# pairplot(): 산점도를 수치형변수에 그려주는 차트

# %%
sns.pairplot(df_dia[['carat','cut','color','price']], hue='cut')

# %%
sns.pairplot(df_dia[['carat','x','y','z','cut','price']],hue=cut)

# %% [markdown]
# # plotly 시각화

# %%
import plotly.express as px

# %%
df_iris = px.data.iris()
df_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
px.scatter(df_iris,x='sepal_width',y='sepal_length')

# %%
df_gapminder=px.data.gapminder()
df_gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
#  6   iso_alpha  1704 non-null   object
#  7   iso_num    1704 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 106.6+ KB

# %%
px.line(df_gapminder,x='year',y='lifeExp',color='continent')

# %%
px.line(df_gapminder.query("continent=='Asia'"), x='year',y='lifeExp', color='country', symbol='country')

# %% [markdown]
# # folium 으로 지도 시각화하기

# %%
#pip install folium

# %%
import folium

# %%
m = folium.Map(location=[37.512957,126.938633], zoom_start=12)
m.save('map.html')
folium.Marker([37.512957,126.938633],popup='Hi IGrowth').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
m = folium.Map(location=[37.502939,126.956337], zoom_start=12)
m.save('map.html')
folium.Marker([37.502939,126.956337],popup='Hi CAU').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
# 출발지와 도착지 좌표 (위도, 경도)
start_coords = (37.513825, 126.941574)  # 노량진역 :contentReference[oaicite:4]{index=4}
end_coords   = (37.5260,   126.8970)    # 국회대로34길 18-2 (추정값) :contentReference[oaicite:5]{index=5}

# 지도 생성 (초기 위치 출발지 기준)
m = folium.Map(location=start_coords, zoom_start=13)

# 출발지 마커
folium.Marker(
    [start_lat, start_lon],
    popup="출발지: 노량진역",
    icon=folium.Icon(color="blue")
).add_to(m)

# 도착지 마커
folium.Marker(
    [end_lat, end_lon],
    popup="도착지: 국회대로34길 18-2",
    icon=folium.Icon(color="red")
).add_to(m)

# 출발지-도착지 선 추가
folium.PolyLine(
    locations=[start_coords, end_coords],
    color="blue",
    weight=5,
    opacity=0.7
).add_to(m)

# 결과 지도 저장
m.save("noryangjin_to_gukhoedaero34_18_2.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
import folium
import requests

# 출발지 / 도착지 좌표 (위도, 경도)
start_lat, start_lon = 37.51446, 126.94267   # 노량진역
end_lat, end_lon     = 37.52629, 126.89663   # 국회대로34길 18-2

# OSRM API 요청 (driving 기준 최적경로)
url = (
    f"http://router.project-osrm.org/route/v1/driving/"
    f"{start_lon},{start_lat};{end_lon},{end_lat}"
    f"?overview=full&geometries=geojson"
)

response = requests.get(url)
data = response.json()

# 경로 좌표 추출 (lon, lat → lat, lon)
route_coords = [
    (lat, lon) for lon, lat in data["routes"][0]["geometry"]["coordinates"]
]

# 지도 생성 (출발지 기준)
m = folium.Map(location=[start_lat, start_lon], zoom_start=13)

# 출발지 마커
folium.Marker(
    [start_lat, start_lon],
    popup="출발지: 노량진역",
    icon=folium.Icon(color="blue")
).add_to(m)

# 도착지 마커
folium.Marker(
    [end_lat, end_lon],
    popup="도착지: 국회대로34길 18-2",
    icon=folium.Icon(color="red")
).add_to(m)

# 최적경로 표시
folium.PolyLine(
    route_coords,
    color="green",
    weight=5,
    opacity=0.8
).add_to(m)

# 지도 출력
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
